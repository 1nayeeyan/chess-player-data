# %% [markdown]
# # Imports

# %%
import requests
import csv
import json
import pycountry
import os
import pandas as pd

cwd = os.getcwd()
country_data_folder = os.path.join(cwd, "country_data")

# create the country_data_folder if it doesn't exist
if not os.path.exists(country_data_folder):
    os.makedirs(country_data_folder)

# Get a list of all country ISO codes
country_codes = [country.alpha_2 for country in pycountry.countries]

for iso in country_codes:
    # send a GET request to the API endpoint with the specified country code
    c_code = iso
    
    # define the API endpoint URL
    url = 'https://api.chess.com/pub/country/' + c_code + '/players'
    
    user_response = requests.get(url)

    # check if the response was successful
    if user_response.status_code == 200:

        data_json = user_response.json()
        
        user_list=[]
        
        for v in data_json["players"]:
            user_list.append(v)
        
        players_data = {
             'Usernames' : user_list,
         }
        
        # create a pandas DataFrame
        df = pd.DataFrame(players_data)
    
        # create a CSV fil and write the header row
        filename = os.path.join(country_data_folder, 'players_username_' + iso + '.csv')
        
        #write the dataframe to the csv
        df.to_csv(filename, index=False, header=False)
        
        print('Data saved to players_username_' + iso + '.csv')
    else:
        print('Error retrieving data from API' + iso)
# Out:
# Data saved to players_username_AW.csv
# Data saved to players_username_AF.csv
# Data saved to players_username_AO.csv
# Data saved to players_username_AI.csv
# Data saved to players_username_AX.csv
# Data saved to players_username_AL.csv
# Data saved to players_username_AD.csv
# Data saved to players_username_AE.csv
# Data saved to players_username_AR.csv
# Data saved to players_username_AM.csv
# Data saved to players_username_AS.csv
# Error retrieving data from APIAQ
# Error retrieving data from APITF
# Data saved to players_username_AG.csv
# Data saved to players_username_AU.csv
# Data saved to players_username_AT.csv
# Data saved to players_username_AZ.csv
# Data saved to players_username_BI.csv
# Data saved to players_username_BE.csv
# Data saved to players_username_BJ.csv
# Error retrieving data from APIBQ
# Data saved to players_username_BF.csv
# Data saved to players_username_BD.csv
# Data saved to players_username_BG.csv
# Data saved to players_username_BH.csv
# Data saved to players_username_BS.csv
# Data saved to players_username_BA.csv
# Error retrieving data from APIBL
# Data saved to players_username_BY.csv
# Data saved to players_username_BZ.csv
# Data saved to players_username_BM.csv
# Data saved to players_username_BO.csv
# Data saved to players_username_BR.csv
# Data saved to players_username_BB.csv
# Data saved to players_username_BN.csv
# Data saved to players_username_BT.csv
# Error retrieving data from APIBV
# Data saved to players_username_BW.csv
# Data saved to players_username_CF.csv
# Data saved to players_username_CA.csv
# Error retrieving data from APICC
# Data saved to players_username_CH.csv
# Data saved to players_username_CL.csv
# Data saved to players_username_CN.csv
# Data saved to players_username_CI.csv
# Data saved to players_username_CM.csv
# Data saved to players_username_CD.csv
# Data saved to players_username_CG.csv
# Error retrieving data from APICK
# Data saved to players_username_CO.csv
# Data saved to players_username_KM.csv
# Data saved to players_username_CV.csv
# Data saved to players_username_CR.csv
# Data saved to players_username_CU.csv
# Data saved to players_username_CW.csv
# Error retrieving data from APICX
# Data saved to players_username_KY.csv
# Data saved to players_username_CY.csv
# Data saved to players_username_CZ.csv
# Data saved to players_username_DE.csv
# Data saved to players_username_DJ.csv
# Data saved to players_username_DM.csv
# Data saved to players_username_DK.csv
# Data saved to players_username_DO.csv
# Data saved to players_username_DZ.csv
# Data saved to players_username_EC.csv
# Data saved to players_username_EG.csv
# Data saved to players_username_ER.csv
# Data saved to players_username_EH.csv
# Data saved to players_username_ES.csv
# Data saved to players_username_EE.csv
# Data saved to players_username_ET.csv
# Data saved to players_username_FI.csv
# Data saved to players_username_FJ.csv
# Data saved to players_username_FK.csv
# Data saved to players_username_FR.csv
# Data saved to players_username_FO.csv
# Data saved to players_username_FM.csv
# Data saved to players_username_GA.csv
# Data saved to players_username_GB.csv
# Data saved to players_username_GE.csv
# Data saved to players_username_GG.csv
# Data saved to players_username_GH.csv
# Data saved to players_username_GI.csv
# Data saved to players_username_GN.csv
# Data saved to players_username_GP.csv
# Data saved to players_username_GM.csv
# Data saved to players_username_GW.csv
# Data saved to players_username_GQ.csv
# Data saved to players_username_GR.csv
# Data saved to players_username_GD.csv
# Data saved to players_username_GL.csv
# Data saved to players_username_GT.csv
# Data saved to players_username_GF.csv
# Data saved to players_username_GU.csv
# Data saved to players_username_GY.csv
# Data saved to players_username_HK.csv
# Error retrieving data from APIHM
# Data saved to players_username_HN.csv
# Data saved to players_username_HR.csv
# Data saved to players_username_HT.csv
# Data saved to players_username_HU.csv
# Data saved to players_username_ID.csv
# Data saved to players_username_IM.csv
# Data saved to players_username_IN.csv
# Error retrieving data from APIIO
# Data saved to players_username_IE.csv
# Data saved to players_username_IR.csv
# Data saved to players_username_IQ.csv
# Data saved to players_username_IS.csv
# Data saved to players_username_IL.csv
# Data saved to players_username_IT.csv
# Data saved to players_username_JM.csv
# Data saved to players_username_JE.csv
# Data saved to players_username_JO.csv
# Data saved to players_username_JP.csv
# Data saved to players_username_KZ.csv
# Data saved to players_username_KE.csv
# Data saved to players_username_KG.csv
# Data saved to players_username_KH.csv
# Data saved to players_username_KI.csv
# Data saved to players_username_KN.csv
# Data saved to players_username_KR.csv
# Data saved to players_username_KW.csv
# Data saved to players_username_LA.csv
# Data saved to players_username_LB.csv
# Data saved to players_username_LR.csv
# Data saved to players_username_LY.csv
# Data saved to players_username_LC.csv
# Data saved to players_username_LI.csv
# Data saved to players_username_LK.csv
# Data saved to players_username_LS.csv
# Data saved to players_username_LT.csv
# Data saved to players_username_LU.csv
# Data saved to players_username_LV.csv
# Data saved to players_username_MO.csv
# Error retrieving data from APIMF
# Data saved to players_username_MA.csv
# Data saved to players_username_MC.csv
# Data saved to players_username_MD.csv
# Data saved to players_username_MG.csv
# Data saved to players_username_MV.csv
# Data saved to players_username_MX.csv
# Data saved to players_username_MH.csv
# Data saved to players_username_MK.csv
# Data saved to players_username_ML.csv
# Data saved to players_username_MT.csv
# Data saved to players_username_MM.csv
# Data saved to players_username_ME.csv
# Data saved to players_username_MN.csv
# Error retrieving data from APIMP
# Data saved to players_username_MZ.csv
# Data saved to players_username_MR.csv
# Data saved to players_username_MS.csv
# Data saved to players_username_MQ.csv
# Data saved to players_username_MU.csv
# Data saved to players_username_MW.csv
# Data saved to players_username_MY.csv
# Data saved to players_username_YT.csv
# Data saved to players_username_NA.csv
# Data saved to players_username_NC.csv
# Data saved to players_username_NE.csv
# Error retrieving data from APINF
# Data saved to players_username_NG.csv
# Data saved to players_username_NI.csv
# Data saved to players_username_NU.csv
# Data saved to players_username_NL.csv
# Data saved to players_username_NO.csv
# Data saved to players_username_NP.csv
# Data saved to players_username_NR.csv
# Data saved to players_username_NZ.csv
# Data saved to players_username_OM.csv
# Data saved to players_username_PK.csv
# Data saved to players_username_PA.csv
# Error retrieving data from APIPN
# Data saved to players_username_PE.csv
# Data saved to players_username_PH.csv
# Data saved to players_username_PW.csv
# Data saved to players_username_PG.csv
# Data saved to players_username_PL.csv
# Data saved to players_username_PR.csv
# Data saved to players_username_KP.csv
# Data saved to players_username_PT.csv
# Data saved to players_username_PY.csv
# Data saved to players_username_PS.csv
# Data saved to players_username_PF.csv
# Data saved to players_username_QA.csv
# Data saved to players_username_RE.csv
# Data saved to players_username_RO.csv
# Data saved to players_username_RU.csv
# Data saved to players_username_RW.csv
# Data saved to players_username_SA.csv
# Data saved to players_username_SD.csv
# Data saved to players_username_SN.csv
# Data saved to players_username_SG.csv
# Data saved to players_username_GS.csv
# Error retrieving data from APISH
# Error retrieving data from APISJ
# Data saved to players_username_SB.csv
# Data saved to players_username_SL.csv
# Data saved to players_username_SV.csv
# Data saved to players_username_SM.csv
# Data saved to players_username_SO.csv
# Data saved to players_username_PM.csv
# Data saved to players_username_RS.csv
# Data saved to players_username_SS.csv
# Data saved to players_username_ST.csv
# Data saved to players_username_SR.csv
# Data saved to players_username_SK.csv
# Data saved to players_username_SI.csv
# Data saved to players_username_SE.csv
# Data saved to players_username_SZ.csv
# Data saved to players_username_SX.csv
# Data saved to players_username_SC.csv
# Data saved to players_username_SY.csv
# Data saved to players_username_TC.csv
# Data saved to players_username_TD.csv
# Data saved to players_username_TG.csv
# Data saved to players_username_TH.csv
# Data saved to players_username_TJ.csv
# Error retrieving data from APITK
# Data saved to players_username_TM.csv
# Data saved to players_username_TL.csv
# Data saved to players_username_TO.csv
# Data saved to players_username_TT.csv
# Data saved to players_username_TN.csv
# Data saved to players_username_TR.csv
# Data saved to players_username_TV.csv
# Data saved to players_username_TW.csv
# Data saved to players_username_TZ.csv
# Data saved to players_username_UG.csv
# Data saved to players_username_UA.csv
# Error retrieving data from APIUM
# Data saved to players_username_UY.csv
# Data saved to players_username_US.csv
# Data saved to players_username_UZ.csv
# Data saved to players_username_VA.csv
# Data saved to players_username_VC.csv
# Data saved to players_username_VE.csv
# Data saved to players_username_VG.csv
# Data saved to players_username_VI.csv
# Data saved to players_username_VN.csv
# Data saved to players_username_VU.csv
# Error retrieving data from APIWF
# Data saved to players_username_WS.csv
# Data saved to players_username_YE.csv
# Data saved to players_username_ZA.csv
# Data saved to players_username_ZM.csv
# Data saved to players_username_ZW.csv

# %% [markdown]
# The error for certain countries, stem from players of that country not being on chess.com. So far, we have each file containing usernames of each player in each country. Now, I'm going to collect the names of the top 10 countries with most players.

# %%
import dask.dataframe as dd
import os

# Get a list of all CSV files in the directory
csv_files = [file for file in os.listdir(country_data_folder) if file.endswith('.csv')]

# Create a dictionary to store row counts
row_counts = {}

# Iterate over each CSV file and get the row count
for file in csv_files:
    # Construct the file path
    file_path = os.path.join(country_data_folder, file)

    # Read the CSV file into a Dask DataFrame
    df = dd.read_csv(file_path)

    # Count the number of rows in the DataFrame
    row_count = len(df)

    # Store the row count in the dictionary
    row_counts[file] = row_count

# Sort the row counts dictionary by value in descending order
sorted_files = sorted(row_counts.items(), key=lambda x: x[1], reverse=True)

# Get the top 10 files with the most rows
largest_files = sorted_files[:10]

# Print the result
print("Top 10 files with the most rows:")
for file, count in largest_files:
    print("File:", file)
    print("Number of rows:", count)
    print()
# Out:
# Top 10 files with the most rows:
# File: players_username_AE.csv
# Number of rows: 9999
#
# File: players_username_AL.csv
# Number of rows: 9999
#
# File: players_username_AM.csv
# Number of rows: 9999
#
# File: players_username_AR.csv
# Number of rows: 9999
#
# File: players_username_AT.csv
# Number of rows: 9999
#
# File: players_username_AU.csv
# Number of rows: 9999
#
# File: players_username_AZ.csv
# Number of rows: 9999
#
# File: players_username_BD.csv
# Number of rows: 9999
#
# File: players_username_BE.csv
# Number of rows: 9999
#
# File: players_username_BG.csv
# Number of rows: 9999

# %% [markdown]
# I have found that there is a limit to requests for the api, I have contacted the chess.com support team for further assistance.

# %%
import csv
import requests
# Define the API endpoint URL
url = 'https://api.chess.com/pub/player/'


# Loop through each country code
for iso in country_codes:
    # Open the CSV file containing the players for this country
    #print(country_data_folder + f'\players_username_{iso}.csv')
    if os.path.exists(country_data_folder + f'\players_username_{iso}.csv'):
        with open(country_data_folder + f'\players_username_{iso}.csv', 'r') as file:
            reader = csv.reader(file)
            next(reader)  # Skip the header row
        
            # Open a new CSV file to write the player data to
            with open(f'player_data_{iso}.csv', 'w', newline='') as output_file:
                writer = csv.writer(output_file)
            
                # Write the header row
                writer.writerow(['username', 'player_id', 'status', 'country', 'joined', 'is_streamer', 'fide'])
            
                # Loop through each player in the input CSV file
                for row in reader:
                    username = row[0]
                
                    # Send a GET request to the API endpoint with the specified username
                    response = requests.get(url + username)
                
                    # Check if the response was successful
                    if response.status_code == 200:
                        # Parse the JSON response
                        data = response.json()
                    
                        # Extract the fields we're interested in
                        player_id = data['player_id']
                        status = data['status']
                        country = data['country']
                        joined = data['joined']
                        is_streamer = data['is_streamer']
                        fide = data.get('fide', '')
                        
                    
                        # Write the data to the output CSV file
                        writer.writerow([username, player_id, status, country, joined, is_streamer, fide])
                        print(f'Written successfully')
                    else:
                        print(f'Error retrieving data for {username} from API')
# Out:
# Written successfully
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16560\1987799530.py in <module>
#      45                         writer.writerow([username, player_id, status, country, joined, is_streamer, fide])
#      46                         print(f'Written successfully')
# ---> 47                         next(reader)
#      48                     else:
#      49                         print(f'Error retrieving data for {username} from API')
#
# StopIteration:

# %%
# Out:
# Data saved to players_username_AW.csv
# Data saved to players_username_AF.csv
# Data saved to players_username_AO.csv
# Data saved to players_username_AI.csv
# Data saved to players_username_AX.csv
# Data saved to players_username_AL.csv
# Data saved to players_username_AD.csv
# Data saved to players_username_AE.csv
# Data saved to players_username_AR.csv
# Data saved to players_username_AM.csv
# Data saved to players_username_AS.csv
# Error retrieving data from APIAQ
# Error retrieving data from APITF
# Data saved to players_username_AG.csv
# Data saved to players_username_AU.csv
# Data saved to players_username_AT.csv
# Data saved to players_username_AZ.csv
# Data saved to players_username_BI.csv
# Data saved to players_username_BE.csv
# Data saved to players_username_BJ.csv
# Error retrieving data from APIBQ
# Data saved to players_username_BF.csv
# Data saved to players_username_BD.csv
# Data saved to players_username_BG.csv
# Data saved to players_username_BH.csv
# Data saved to players_username_BS.csv
# Data saved to players_username_BA.csv
# Error retrieving data from APIBL
# Data saved to players_username_BY.csv
# Data saved to players_username_BZ.csv
# Data saved to players_username_BM.csv
# Data saved to players_username_BO.csv
# Data saved to players_username_BR.csv
# Data saved to players_username_BB.csv
# Data saved to players_username_BN.csv
# Data saved to players_username_BT.csv
# Error retrieving data from APIBV
# Data saved to players_username_BW.csv
# Data saved to players_username_CF.csv
# Data saved to players_username_CA.csv
# Error retrieving data from APICC
# Data saved to players_username_CH.csv
# Data saved to players_username_CL.csv
# Data saved to players_username_CN.csv
# Data saved to players_username_CI.csv
# Data saved to players_username_CM.csv
# Data saved to players_username_CD.csv
# Data saved to players_username_CG.csv
# Error retrieving data from APICK
# Data saved to players_username_CO.csv
# Data saved to players_username_KM.csv
# Data saved to players_username_CV.csv
# Data saved to players_username_CR.csv
# Data saved to players_username_CU.csv
# Data saved to players_username_CW.csv
# Error retrieving data from APICX
# Data saved to players_username_KY.csv
# Data saved to players_username_CY.csv
# Data saved to players_username_CZ.csv
# Data saved to players_username_DE.csv
# Data saved to players_username_DJ.csv
# Data saved to players_username_DM.csv
# Data saved to players_username_DK.csv
# Data saved to players_username_DO.csv
# Data saved to players_username_DZ.csv
# Data saved to players_username_EC.csv
# Data saved to players_username_EG.csv
# Data saved to players_username_ER.csv
# Data saved to players_username_EH.csv
# Data saved to players_username_ES.csv
# Data saved to players_username_EE.csv
# Data saved to players_username_ET.csv
# Data saved to players_username_FI.csv
# Data saved to players_username_FJ.csv
# Data saved to players_username_FK.csv
# Data saved to players_username_FR.csv
# Data saved to players_username_FO.csv
# Data saved to players_username_FM.csv
# Data saved to players_username_GA.csv
# Data saved to players_username_GB.csv
# Data saved to players_username_GE.csv
# Data saved to players_username_GG.csv
# Data saved to players_username_GH.csv
# Data saved to players_username_GI.csv
# Data saved to players_username_GN.csv
# Data saved to players_username_GP.csv
# Data saved to players_username_GM.csv
# Data saved to players_username_GW.csv
# Data saved to players_username_GQ.csv
# Data saved to players_username_GR.csv
# Data saved to players_username_GD.csv
# Data saved to players_username_GL.csv
# Data saved to players_username_GT.csv
# Data saved to players_username_GF.csv
# Data saved to players_username_GU.csv
# Data saved to players_username_GY.csv
# Data saved to players_username_HK.csv
# Error retrieving data from APIHM
# Data saved to players_username_HN.csv
# Data saved to players_username_HR.csv
# Data saved to players_username_HT.csv
# Data saved to players_username_HU.csv
# Data saved to players_username_ID.csv
# Data saved to players_username_IM.csv
# Data saved to players_username_IN.csv
# Error retrieving data from APIIO
# Data saved to players_username_IE.csv
# Data saved to players_username_IR.csv
# Data saved to players_username_IQ.csv
# Data saved to players_username_IS.csv
# Data saved to players_username_IL.csv
# Data saved to players_username_IT.csv
# Data saved to players_username_JM.csv
# Data saved to players_username_JE.csv
# Data saved to players_username_JO.csv
# Data saved to players_username_JP.csv
# Data saved to players_username_KZ.csv
# Data saved to players_username_KE.csv
# Data saved to players_username_KG.csv
# Data saved to players_username_KH.csv
# Data saved to players_username_KI.csv
# Data saved to players_username_KN.csv
# Data saved to players_username_KR.csv
# Data saved to players_username_KW.csv
# Data saved to players_username_LA.csv
# Data saved to players_username_LB.csv
# Data saved to players_username_LR.csv
# Data saved to players_username_LY.csv
# Data saved to players_username_LC.csv
# Data saved to players_username_LI.csv
# Data saved to players_username_LK.csv
# Data saved to players_username_LS.csv
# Data saved to players_username_LT.csv
# Data saved to players_username_LU.csv
# Data saved to players_username_LV.csv
# Data saved to players_username_MO.csv
# Error retrieving data from APIMF
# Data saved to players_username_MA.csv
# Data saved to players_username_MC.csv
# Data saved to players_username_MD.csv
# Data saved to players_username_MG.csv
# Data saved to players_username_MV.csv
# Data saved to players_username_MX.csv
# Data saved to players_username_MH.csv
# Data saved to players_username_MK.csv
# Data saved to players_username_ML.csv
# Data saved to players_username_MT.csv
# Data saved to players_username_MM.csv
# Data saved to players_username_ME.csv
# Data saved to players_username_MN.csv
# Error retrieving data from APIMP
# Data saved to players_username_MZ.csv
# Data saved to players_username_MR.csv
# Data saved to players_username_MS.csv
# Data saved to players_username_MQ.csv
# Data saved to players_username_MU.csv
# Data saved to players_username_MW.csv
# Data saved to players_username_MY.csv
# Data saved to players_username_YT.csv
# Data saved to players_username_NA.csv
# Data saved to players_username_NC.csv
# Data saved to players_username_NE.csv
# Error retrieving data from APINF
# Data saved to players_username_NG.csv
# Data saved to players_username_NI.csv
# Data saved to players_username_NU.csv
# Data saved to players_username_NL.csv
# Data saved to players_username_NO.csv
# Data saved to players_username_NP.csv
# Data saved to players_username_NR.csv
# Data saved to players_username_NZ.csv
# Data saved to players_username_OM.csv
# Data saved to players_username_PK.csv
# Data saved to players_username_PA.csv
# Error retrieving data from APIPN
# Data saved to players_username_PE.csv
# Data saved to players_username_PH.csv
# Data saved to players_username_PW.csv
# Data saved to players_username_PG.csv
# Data saved to players_username_PL.csv
# Data saved to players_username_PR.csv
# Data saved to players_username_KP.csv
# Data saved to players_username_PT.csv
# Data saved to players_username_PY.csv
# Data saved to players_username_PS.csv
# Data saved to players_username_PF.csv
# Data saved to players_username_QA.csv
# Data saved to players_username_RE.csv
# Data saved to players_username_RO.csv
# Data saved to players_username_RU.csv
# Data saved to players_username_RW.csv
# Data saved to players_username_SA.csv
# Data saved to players_username_SD.csv
# Data saved to players_username_SN.csv
# Data saved to players_username_SG.csv
# Data saved to players_username_GS.csv
# Error retrieving data from APISH
# Error retrieving data from APISJ
# Data saved to players_username_SB.csv
# Data saved to players_username_SL.csv
# Data saved to players_username_SV.csv
# Data saved to players_username_SM.csv
# Data saved to players_username_SO.csv
# Data saved to players_username_PM.csv
# Data saved to players_username_RS.csv
# Data saved to players_username_SS.csv
# Data saved to players_username_ST.csv
# Data saved to players_username_SR.csv
# Data saved to players_username_SK.csv
# Data saved to players_username_SI.csv
# Data saved to players_username_SE.csv
# Data saved to players_username_SZ.csv
# Data saved to players_username_SX.csv
# Data saved to players_username_SC.csv
# Data saved to players_username_SY.csv
# Data saved to players_username_TC.csv
# Data saved to players_username_TD.csv
# Data saved to players_username_TG.csv
# Data saved to players_username_TH.csv
# Data saved to players_username_TJ.csv
# Error retrieving data from APITK
# Data saved to players_username_TM.csv
# Data saved to players_username_TL.csv
# Data saved to players_username_TO.csv
# Data saved to players_username_TT.csv
# Data saved to players_username_TN.csv
# Data saved to players_username_TR.csv
# Data saved to players_username_TV.csv
# Data saved to players_username_TW.csv
# Data saved to players_username_TZ.csv
# Data saved to players_username_UG.csv
# Data saved to players_username_UA.csv
# Error retrieving data from APIUM
# Data saved to players_username_UY.csv
# Data saved to players_username_US.csv
# Data saved to players_username_UZ.csv
# Data saved to players_username_VA.csv
# Data saved to players_username_VC.csv
# Data saved to players_username_VE.csv
# Data saved to players_username_VG.csv
# Data saved to players_username_VI.csv
# Data saved to players_username_VN.csv
# Data saved to players_username_VU.csv
# Error retrieving data from APIWF
# Data saved to players_username_WS.csv
# Data saved to players_username_YE.csv
# Data saved to players_username_ZA.csv
# Data saved to players_username_ZM.csv
# Data saved to players_username_ZW.csv
# Top 10 countries with the most entries:
# Country: Albania
# Number of entries: 10000
#
# Country: United Arab Emirates
# Number of entries: 10000
#
# Country: Argentina
# Number of entries: 10000
#
# Country: Armenia
# Number of entries: 10000
#
# Country: Australia
# Number of entries: 10000
#
# Country: Austria
# Number of entries: 10000
#
# Country: Azerbaijan
# Number of entries: 10000
#
# Country: Belgium
# Number of entries: 10000
#
# Country: Bangladesh
# Number of entries: 10000
#
# Country: Bulgaria
# Number of entries: 10000

# %%
# Out:
# Data saved to players_username_FR.csv
